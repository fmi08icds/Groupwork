# %% [markdown]
# # Spotify Dataset Description

# %%
# Modify sys.path to allow imports of own modules
import os
import sys

BASE_DIR = os.path.join(os.path.abspath(""), "..")
sys.path.insert(0, BASE_DIR)

from data import datasource as ds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Download the Spotify Track Dataset here: https://www.kaggle.com/datasets/zaheenhamidani/ultimate-spotify-tracks-db
#
# Unzip and store the csv-file in the same directory or change variable path to your path.

# %%
path = os.path.join(BASE_DIR, "data", "SpotifyFeatures.csv")

# %% [markdown]
# load_spotify_dataset(path) will load the original dataset from the SpotifyFeatures.csv into data.

# %%
data = ds.load_spotify_dataset(path=path)
data.head(10)
# Out:
#    genre          artist_name  \
# 0  Movie       Henri Salvador
# 1  Movie    Martin & les fées
# 2  Movie      Joseph Williams
# 3  Movie       Henri Salvador
# 4  Movie         Fabien Nataf
# 5  Movie       Henri Salvador
# 6  Movie    Martin & les fées
# 7  Movie          Laura Mayne
# 8  Movie               Chorus
# 9  Movie  Le Club des Juniors
#
#                                           track_name                track_id  \
# 0                        C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                   Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2                     Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3                     Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                          Ouverture  0IuslXpMROHdEPvSl1fTQK
# 5                     Le petit souper aux chandelles  0Mf1jKa8eNAf1a4PwTbizj
# 6  Premières recherches (par Paul Ventimila, Lori...  0NUiKYRd6jt1LKMYGkUdnZ
# ...

# %% [markdown]
# load_X_y(path, attribute_list, sample_size) extracts the feature matrix X and the vector y as numpy arrays.
#
# - Path: your path to SpotifyFeatures.csv
# - attribute_list:  Choose attributes from ['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
# - sample_size: 100 as default

# %%
X, y, df = ds.load_X_y(path=path)

print(X.shape)
print(y.shape)
# Out:
# (2600, 10)
# (2600, 1)

# %% [markdown]
# ## Data Exploration

# %%
column_names = data.columns.tolist()
column_names
# Out:
# ['genre',
#  'artist_name',
#  'track_name',
#  'track_id',
#  'popularity',
#  'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence']

# %%
data['time_signature'].unique()
# Out:
# array(['4/4', '5/4', '3/4', '1/4', '0/4'], dtype=object)

# %%
data['popularity'].unique()
# Out:
# array([  0,   1,   3,   4,   2,  15,  10,   8,   5,   6,   7,  11,  65,
#         63,  62,  61,  68,  64,  66,  60,  69,  71,  76,  67,  70,  72,
#         57,  59,  56,  28,  31,  74,  55,  53,   9,  13,  23,  12,  44,
#         33,  25,  26,  24,  22,  20,  19,  18,  16,  17,  14,  83,  81,
#         73,  78,  77,  75,  45,  42,  46,  54,  41,  52,  58,  51,  43,
#         47,  48,  40,  50,  49,  39,  80,  37,  35,  21,  38,  36,  29,
#         34,  32,  99, 100,  97,  92,  91,  95,  90,  93,  88,  87,  89,
#         96,  86,  85,  84,  94,  82,  79,  27,  30,  98])

# %%
data['key'].unique()
# Out:
# array(['C#', 'F#', 'C', 'F', 'G', 'E', 'D#', 'G#', 'D', 'A#', 'A', 'B'],
#       dtype=object)

# %%
data['mode'].unique()
# Out:
# array(['Major', 'Minor'], dtype=object)

# %%
attribute_list = ['popularity', 
 'acousticness',
 'danceability',
 'duration_ms',
 'energy',
 'instrumentalness',
 'liveness',
 'loudness',
 'speechiness',
 'tempo',
 'valence']

for attribute in attribute_list:

    plt.hist(data[attribute], bins=20, color='lightblue',edgecolor='black')
    plt.xlabel('Index')
    plt.ylabel('# Spotify Tracks')
    plt.title(attribute)
    plt.show()

# %%
plt.hist(data['energy'], bins=20, color='lightblue',edgecolor='black')
plt.xlabel('Energy Index')
plt.ylabel('# Spotify Tracks')
plt.title('Energy')
# Out:
# Text(0.5, 1.0, 'Energy')

# %%
plt.hist(data['tempo'], bins=20, color='lightblue',edgecolor='black')
plt.xlabel('BPM')
plt.ylabel('# Spotify Tracks')
plt.title('Tempo')
# Out:
# Text(0.5, 1.0, 'Tempo')

# %%
unique_genre = data['genre'].nunique()

# %%
plt.hist(data['genre'], bins=27,color='lightblue',edgecolor='black')
plt.xticks(rotation='vertical')
plt.xlabel('Genre')
plt.ylabel('# Spotify Tracks')
plt.title('Genre')
# Out:
# Text(0.5, 1.0, 'Genre')

# %%
data['genre'].value_counts()
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64

# %%
data[data['genre'] == "A Capella"]
# Out:
#          genre            artist_name               track_name  \
# 552  A Capella         MC6 A Cappella     For the Longest Time
# 553  A Capella  The Singers Unlimited                    Clair
# 554  A Capella         MC6 A Cappella          Come Go With Me
# 555  A Capella         MC6 A Cappella  The Lion Sleeps Tonight
# 556  A Capella                   Glad  A Debtor to Mercy Alone
# ..         ...                    ...                      ...
# 666  A Capella     The King's Singers      When I Fall in Love
# 667  A Capella     The King's Singers                  At Last
# 668  A Capella     The King's Singers            Night and Day
# 669  A Capella     The King's Singers           Cry Me a River
# 670  A Capella     The King's Singers       My Funny Valentine
#
#                    track_id  popularity  acousticness  danceability  \
# 552  0PuWvFJqZPJAxZNrFgw8xL          44         0.780         0.616
# 553  1iXJKuzDH0E6PnTk2lQXAq          33         0.973         0.484
# ...

# %%
# as we can see 'Children's music' is apearing with different apostroph
# so we choose to delete 'Children's music' with 5403 occurrence
data = data[data['genre'] != "Children's Music"]
data['genre'].value_counts()

#data.loc[data['genre'] == "Children’s Music",'genre'] = "Children's Music"
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# A Capella            119
# Name: genre, dtype: int64

# %%
plt.hist(data['genre'], bins=26,color='lightblue',edgecolor='black')
plt.xticks(rotation='vertical')
plt.xlabel('Genre')
plt.ylabel('# Spotify Tracks')
plt.title('Genre')
# Out:
# Text(0.5, 1.0, 'Genre')

# %%
data[data['genre'] == "Children's Music"]
# Out:
# Empty DataFrame
# Columns: [genre, artist_name, track_name, track_id, popularity, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence]
# Index: []

# %%
# remove now all double values in "Children’s Music"
data.drop_duplicates(subset=['genre','artist_name','track_name'])
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
plt.hist(data['genre'], bins=26,color='lightblue',edgecolor='black')
plt.xticks(rotation='vertical')
plt.xlabel('Genre')
plt.ylabel('# Spotify Tracks')
plt.title('Genre')
# Out:
# Text(0.5, 1.0, 'Genre')

# %% [markdown]
# Info shows that just one track_name is missing. Can be ignored for our clustering.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227322 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             227322 non-null  object
#  1   artist_name       227322 non-null  object
#  2   track_name        227322 non-null  object
#  3   track_id          227322 non-null  object
#  4   popularity        227322 non-null  int64
#  5   acousticness      227322 non-null  float64
#  6   danceability      227322 non-null  float64
#  7   duration_ms       227322 non-null  int64
#  8   energy            227322 non-null  float64
#  9   instrumentalness  227322 non-null  float64
#  10  key               227322 non-null  object
#  11  liveness          227322 non-null  float64
#  12  loudness          227322 non-null  float64
#  13  mode              227322 non-null  object
#  14  speechiness       227322 non-null  float64
# ...

# %%
# 1 track without name
data[data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [genre, artist_name, track_name, track_id, popularity, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence]
# Index: []

# %%
data.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  227322.000000  227322.000000  227322.000000  2.273220e+05
# mean       42.003946       0.363255       0.550963  2.373184e+05
# std        17.439490       0.353977       0.184913  1.188972e+05
# min         0.000000       0.000000       0.056900  1.550900e+04
# 25%        30.000000       0.035600       0.432000  1.850785e+05
# 50%        44.000000       0.223000       0.567000  2.217360e+05
# 75%        55.000000       0.714000       0.688000  2.670000e+05
# max       100.000000       0.996000       0.987000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  227322.000000     227322.000000  227322.000000  227322.000000
# mean        0.575095          0.148414       0.216200      -9.520641
# std         0.263276          0.302739       0.199341       6.024007
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %%
data['genre'].value_counts()
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# A Capella            119
# Name: genre, dtype: int64

# %%
data['genre'].nunique()
# Out:
# 26

# %%
data.notna().count()
# Out:
# genre               227322
# artist_name         227322
# track_name          227322
# track_id            227322
# popularity          227322
# acousticness        227322
# danceability        227322
# duration_ms         227322
# energy              227322
# instrumentalness    227322
# key                 227322
# liveness            227322
# loudness            227322
# mode                227322
# speechiness         227322
# tempo               227322
# time_signature      227322
# valence             227322
# dtype: int64

# %%
data['artist_name'].value_counts().head(10)
# Out:
# Giuseppe Verdi             1394
# Giacomo Puccini            1137
# Nobuo Uematsu               825
# Richard Wagner              804
# Wolfgang Amadeus Mozart     800
# Randy Newman                757
# Georges Bizet               701
# Johann Sebastian Bach       632
# Ludwig van Beethoven        596
# Hans Zimmer                 559
# Name: artist_name, dtype: int64

# %%
data['artist_name'].nunique()
# Out:
# 14400

# %%
data['track_name'].value_counts()
# Out:
# Home                              100
# You                                71
# Intro                              68
# Stay                               63
# Closer                             58
#                                  ...
# All The Time 2                      1
# U.N.I.T.Y.                          1
# Drive Slow / Taste Like Heaven      1
# Loca (feat. Duki, Cazzu)            1
# You Don't Have To Hurt No More      1
# Name: track_name, Length: 144676, dtype: int64
